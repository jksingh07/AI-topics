# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Importing Libraries

# %%
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.mixture import GaussianMixture
from sklearn import svm
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd

# %% [markdown]
# # Spiral Dataset

# %%
# Ques 2 
#a. k-means: 
#b. EM
#c. Spectral clustering

# %%
import pandas as pd


df = pd.read_csv('/content/sample_data/spiral1.csv')


X=df[['x','y']]
y=df['label']
X=X.values

# %%
df.head()
# Out:
#          x         y  label
# 0 -1.60023   7.69407    0.0
# 1  7.03777   9.76350    1.0
# 2  9.29608  -9.16002    0.0
# 3  3.95189  12.31531    1.0
# 4  0.56410   4.34127    0.0

# %% [markdown]
# ## K MEANS

# %%
from sklearn.cluster import KMeans

#k means
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels_ = kmeans.labels_
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("K-Means Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)
df_2
# Out:
#             x         y  label  0
# 0    -1.60023   7.69407    0.0  1
# 1     7.03777   9.76350    1.0  1
# 2     9.29608  -9.16002    0.0  0
# 3     3.95189  12.31531    1.0  1
# 4     0.56410   4.34127    0.0  1
# ..        ...       ...    ... ..
# 995  14.23334  -2.59433    0.0  0
# 996   1.54775  10.99383    1.0  1
# 997   8.59973   2.69069    1.0  0
# 998  -7.24296   3.13314    0.0  1
# 999   7.24604 -10.25400    0.0  0
#
# [1000 rows x 4 columns]

# %%
markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0.0]['x'], df_2[df_2[0]==0.0]['y'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x'], df_2[df_2[0]==1]['y'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0.0]['x'], df[df['label']==0.0]['y'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1.0]['x'], df[df['label']==1.0]['y'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
##

# %% [markdown]
# ## EM Clustering

# %%
# EM Clustering


gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(X)
labels_ = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("EM Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)
df_2
# Out:
#             x         y  label  0
# 0    -1.60023   7.69407    0.0  1
# 1     7.03777   9.76350    1.0  1
# 2     9.29608  -9.16002    0.0  0
# 3     3.95189  12.31531    1.0  1
# 4     0.56410   4.34127    0.0  1
# ..        ...       ...    ... ..
# 995  14.23334  -2.59433    0.0  0
# 996   1.54775  10.99383    1.0  1
# 997   8.59973   2.69069    1.0  1
# 998  -7.24296   3.13314    0.0  1
# 999   7.24604 -10.25400    0.0  0
#
# [1000 rows x 4 columns]

# %%
markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0.0]['x'], df_2[df_2[0]==0.0]['y'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x'], df_2[df_2[0]==1]['y'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0.0]['x'], df[df['label']==0.0]['y'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1.0]['x'], df[df['label']==1.0]['y'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## Spectral Clustering

# %%
# Spectral Clustering
#choosing rbf kernel
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', random_state=0)
labels_ = sc.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_,cmap='Dark2')
plt.title("Spectral Clustering on Spiral")
plt.show()
# Out:
# "In this code, the SpectralClustering class from the sklearn library is used to implement Spectral Clustering.\n The number of clusters is set to 2, and the affinity parameter is set to 'rbf' to use the RBF kernel. The fit_predict\n  method is used to fit the model and obtain the cluster assignments. Finally, a scatter plot of the data is produced,\n   colored according to the cluster assignments.\n\n\nThe RBF kernel was chosen because it is a popular choice for Spectral Clustering and has been shown to work well in \nmany cases. The RBF kernel measures the similarity between two points based on the distance between them. It is well-suited \nfor clustering data that is non-linearly separable, which may be the case for the circles0.3 dataset. "

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)
df_2
# Out:
#             x         y  label  0
# 0    -1.60023   7.69407    0.0  0
# 1     7.03777   9.76350    1.0  0
# 2     9.29608  -9.16002    0.0  1
# 3     3.95189  12.31531    1.0  0
# 4     0.56410   4.34127    0.0  0
# ..        ...       ...    ... ..
# 995  14.23334  -2.59433    0.0  1
# 996   1.54775  10.99383    1.0  0
# 997   8.59973   2.69069    1.0  0
# 998  -7.24296   3.13314    0.0  1
# 999   7.24604 -10.25400    0.0  1
#
# [1000 rows x 4 columns]

# %%
markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0.0]['x'], df_2[df_2[0]==0.0]['y'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x'], df_2[df_2[0]==1]['y'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0.0]['x'], df[df['label']==0.0]['y'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1.0]['x'], df[df['label']==1.0]['y'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
#markers = ["x","o"]
#colors = ['black','r']
#plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

#plt.scatter(df[df['label']==0.0]['x'], df[df['label']==0.0]['y'],c=colors[0], marker=markers[0], cmap='Spectral',s=100)
#plt.scatter(df[df['label']==1.0]['x'], df[df['label']==1.0]['y'],c=colors[0], marker=markers[1], cmap='Spectral',s=100)
#plt.scatter(df_2[df_2[0]==0.0]['x'], df_2[df_2[0]==0.0]['y'],c=colors[1], marker=markers[0], cmap='Spectral',s=60)
#plt.scatter(df_2[df_2[0]==1]['x'], df_2[df_2[0]==1]['y'],c=colors[1], marker=markers[1], cmap='Spectral',s=60)

# %%
#Question 3
#Add the original class labels to the existing clusters and plot the points as follows:
#points in the new cluster should have the same shape; points in the original class should have the same color.

# %%
# import matplotlib.pyplot as plt# Assign cluster labels to each data point based on clustering results
# # Assume 'labels_kmeans', 'labels_em', and 'labels_spectral' contain the cluster labels for each algorithm# Plot k-means clusters with circles and original labels with red/blue colors

# plt.scatter(X[labels_kmeans == 0, 0], X[labels_kmeans == 0, 1], s=50, c='r', marker='o', label='Class A')
# plt.scatter(X[labels_kmeans == 1, 0], X[labels_kmeans == 1, 1], s=50, c='b', marker='o', label='Class B')
# plt.scatter(centers_kmeans[:, 0], centers_kmeans[:, 1], s=200, c='black', marker='x', label='Centroids')

# plt.title('k-means clustering with original labels')
# plt.legend(loc='best')
# plt.show()# Plot EM clusters with triangles and original labels with red/blue colors
# plt.scatter(X[labels_em == 0, 0], X[labels_em == 0, 1], s=50, c='r', marker='^', label='Class A')
# plt.scatter(X[labels_em == 1, 0], X[labels_em == 1, 1], s=50, c='b', marker='^', label='Class B')
# plt.title('EM clustering with original labels')
# plt.legend(loc='best')
# plt.show()# Plot Spectral clustering with diamonds and original labels with red/blue colors
# plt.scatter(X[labels_spectral == 0, 0], X[labels_spectral == 0, 1], s=50, c='r', marker='D', label='Class A')
# plt.scatter(X[labels_spectral == 1, 0], X[labels_spectral == 1, 1], s=50, c='b', marker='D', label='Class B')
# plt.title('Spectral clustering with original labels')
# plt.legend(loc='best')
# plt.show()\

# %%
#ques 4
#only theory

# %%
#Ques 5
#The best value of k, the number of clusters, can be determined using various methods, including the elbow method 


from yellowbrick.cluster import KElbowVisualizer
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()
#Therefore, from figure it can be seen that the optimal number of clusters is 4.



#answer 5(B)
'''The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the 
within-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS
 measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.
  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. 
  The index of validity can be used to compare different
 clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'''
# Out:
# 'The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the \nwithin-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS\n measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.\n  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. \n  The index of validity can be used to compare different\n clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'

# %% [markdown]
# # Applying above models on ALL Datasets

# %% [markdown]
# # Circles Dataset

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'label'], dtype='object')

# %%
df = pd.read_csv('/content/sample_data/circles0.3.csv')


X=df[['x1','x2']]
y=df['label']
X=X.values

# %% [markdown]
# ## K Means

# %%
#k means
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels_ = kmeans.labels_
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("K-Means Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)
df_2 = pd.concat([df, labels_], axis=1)
markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])
plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## EM

# %%
# EM Clustering


gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(X)
labels_ = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("EM Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## SPECTRAL

# %%
# Spectral Clustering
#choosing rbf kernel
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', random_state=0)
labels_ = sc.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_,cmap='Dark2')
plt.title("Spectral Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
#Ques 5
#The best value of k, the number of clusters, can be determined using various methods, including the elbow method 


from yellowbrick.cluster import KElbowVisualizer
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()
#Therefore, from figure it can be seen that the optimal number of clusters is 4.



#answer 5(B)
'''The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the 
within-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS
 measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.
  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. 
  The index of validity can be used to compare different
 clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'''
# Out:
# 'The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the \nwithin-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS\n measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.\n  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. \n  The index of validity can be used to compare different\n clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'

# %% [markdown]
# ## Moons1 Dataset

# %%
df = pd.read_csv('/content/sample_data/moons1.csv')

# %%
X=df[['x1','x2']]
y=df['label']
X=X.values
df.head()
# Out:
#          x1        x2  label
# 0 -0.674481  0.469321      0
# 1  0.566712 -0.284153      1
# 2 -0.257384  0.230913      1
# 3  1.868980  0.610969      1
# 4 -0.579194  0.842457      0

# %% [markdown]
# ## K MEANS

# %%
#k means
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels_ = kmeans.labels_
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("K-Means Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## EM

# %%
# EM Clustering


gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(X)
labels_ = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("EM Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## SPECTRAL

# %%
# Spectral Clustering
#choosing rbf kernel
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', random_state=0)
labels_ = sc.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_,cmap='Dark2')
plt.title("Spectral Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
#Ques 5
#The best value of k, the number of clusters, can be determined using various methods, including the elbow method 


from yellowbrick.cluster import KElbowVisualizer
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()
#Therefore, from figure it can be seen that the optimal number of clusters is 4.



#answer 5(B)
'''The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the 
within-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS
 measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.
  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. 
  The index of validity can be used to compare different
 clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'''
# Out:
# 'The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the \nwithin-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS\n measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.\n  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. \n  The index of validity can be used to compare different\n clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'

# %% [markdown]
# # Half Kernel Dataset

# %%
df = pd.read_csv('/content/sample_data/halfkernel.csv')
df.head()
# Out:
#      x1     x2  label
# 0 -2.93  -9.01      0
# 1 -9.33  11.40      0
# 2 -3.36   4.51      0
# 3 -7.29  10.40      0
# 4 -9.72 -12.00      0

# %%
X=df[['x1','x2']]
y=df['label']
X=X.values

# %% [markdown]
# ## K MEANS

# %%
#k means
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels_ = kmeans.labels_
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("K-Means Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## EM

# %%
# EM Clustering


gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(X)
labels_ = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("EM Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## SPECTRAL

# %%
# Spectral Clustering
#choosing rbf kernel
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', random_state=0)
labels_ = sc.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_,cmap='Dark2')
plt.title("Spectral Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
#Ques 5
#The best value of k, the number of clusters, can be determined using various methods, including the elbow method 


from yellowbrick.cluster import KElbowVisualizer
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()
#Therefore, from figure it can be seen that the optimal number of clusters is 4.



#answer 5(B)
'''The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the 
within-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS
 measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.
  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. 
  The index of validity can be used to compare different
 clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'''
# Out:
# 'The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the \nwithin-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS\n measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.\n  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. \n  The index of validity can be used to compare different\n clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'

# %% [markdown]
# # Two Gaussians

# %%
df = pd.read_csv('/content/sample_data/twogaussians42.csv')
df.head()
# Out:
#          x1        x2  label
# 0  0.601034  1.535353      1
# 1  0.755945 -1.172352      0
# 2  1.354479 -0.948528      0
# 3  3.103090  0.233485      0
# 4  0.753178  0.787514      1

# %%
X=df[['x1','x2']]
y=df['label']
X=X.values

# %% [markdown]
# ## K MEANS

# %%
#k means
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
labels_ = kmeans.labels_
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("K-Means Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %% [markdown]
# ## EM

# %%
# EM Clustering


gmm = GaussianMixture(n_components=2, random_state=0)
gmm.fit(X)
labels_ = gmm.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')
plt.title("EM Clustering on Spiral")
plt.show()

# %%
labels_=pd.DataFrame(labels_)

df_2 = pd.concat([df, labels_], axis=1)

markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
# model, cv, y_pred, scores = SVM(x_train, y_train,x_test)
# # summarize result
# print('Mean Accuracy: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
# accuracy, ppv,npv,specificity,sensitivity = get_metrics(y_test, y_pred)
# print(f" Accuracy Score: {accuracy}\n PPV: {ppv}\n NPV: {npv}\n specificity: {specificity}\n sensitivity: {sensitivity}")

# %% [markdown]
# ## SPECTRAL

# %%
# Spectral Clustering
#choosing rbf kernel
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', random_state=0)
labels_ = sc.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels_,cmap='Dark2')
plt.title("Spectral Clustering on Spiral")
plt.show()

# %%
markers = ["x","o"]
colors = ['black','r']
plt.figure(figsize =(15, 15))
#plt.scatter(X[:, 0], X[:, 1], c=labels_, cmap='Spectral')

plt.scatter(df_2[df_2[0]==0]['x1'], df_2[df_2[0]==0]['x2'],c=colors[0], cmap='Spectral',s=100,marker=markers[0])
plt.scatter(df_2[df_2[0]==1]['x1'], df_2[df_2[0]==1]['x2'],c=colors[0],  cmap='Spectral',s=100,marker=markers[1])

plt.scatter(df[df['label']==0]['x1'], df[df['label']==0]['x2'], marker=markers[0], cmap='Spectral',s=40,c=colors[0])
plt.scatter(df[df['label']==1]['x1'], df[df['label']==1]['x2'], marker=markers[1], cmap='Spectral',s=40,c=colors[1])

# %%
#Ques 5
#The best value of k, the number of clusters, can be determined using various methods, including the elbow method 


from yellowbrick.cluster import KElbowVisualizer
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1, 11))

visualizer.fit(X) # Fit the data to the visualizer
visualizer.show() # Finalize and render the figure
plt.show()
#Therefore, from figure it can be seen that the optimal number of clusters is 4.



#answer 5(B)
'''The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the 
within-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS
 measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.
  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. 
  The index of validity can be used to compare different
 clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'''
# Out:
# 'The index of validity is a measure of the quality of the clustering solution. It compares the ratio of the \nwithin-cluster sum of squared distances (WCSS) to the between-cluster sum of squared distances (BCSS). The BCSS\n measures the dissimilarity between the clusters, while the WCSS measures the dissimilarity within the clusters.\n  The index of validity is defined as the ratio BCSS/WCSS, and a higher value indicates a better clustering solution. \n  The index of validity can be used to compare different\n clustering solutions for a fixed value of k, or to compare different values of k for a fixed clustering algorithm.'
